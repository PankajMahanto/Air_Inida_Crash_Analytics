# %% [markdown]
# # <font color='green'> **Air India Ahmedabad Plane Crash Analysis** </font>

# %% [markdown]
# ![crash.png](attachment:crash.png)

# %% [markdown]
# ## 📌 1. Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 📌 2. Incident Data

# %%
incident_data = {
    "Flight Number": ["AI171"],
    "Aircraft Type": ["Boeing 787-8 Dreamliner"],
    "Origin": ["Sardar Vallabhbhai Patel International Airport, Ahmedabad, India"],
    "Destination": ["London Gatwick, United Kingdom"],
    "Date": ["2025-06-12"],
    "Time": ["Afternoon"],
    "Total People Onboard": [242],
    "Passengers": [230],
    "Crew": [12],
    "Crash Location": ["Meghani area, Ahmedabad, India"],
    "Altitude at Crash": ["Approximately 425 feet"],
    "Cause": ["Under investigation (suspected engine failure, safety lapses flagged by DGCA)"],
    "Description": ["Aircraft stalled shortly after takeoff, crashed into a medical college campus, and burst into flames due to heavy fuel load."],
    "Mayday Call": ["Issued before contact was lost"]
}
df_incident = pd.DataFrame(incident_data)
df_incident
# Out:
#   Flight Number            Aircraft Type  \
# 0         AI171  Boeing 787-8 Dreamliner
#
#                                               Origin  \
# 0  Sardar Vallabhbhai Patel International Airport...
#
#                       Destination        Date       Time  \
# 0  London Gatwick, United Kingdom  2025-06-12  Afternoon
#
#    Total People Onboard  Passengers  Crew                  Crash Location  \
# 0                   242         230    12  Meghani area, Ahmedabad, India
#
#         Altitude at Crash                                              Cause  \
# 0  Approximately 425 feet  Under investigation (suspected engine failure,...
#
#                                          Description  \
# 0  Aircraft stalled shortly after takeoff, crashe...
#
#                       Mayday Call
# 0  Issued before contact was lost

# %% [markdown]
# ## 📌 3. Casualties Data

# %%
casualties_data = {
    "Death Toll": [265],
    "Confirmed Deaths": [241],
    "Survivors": [1],
    "Survivor Name": ["Vishwaskumar Ramesh"],
    "Notable Victim 1": ["Vijay Rupani, Former Chief Minister of Gujarat"],
    "Notable Victim 2": ["Payal Khatik, Student, supported family through tutoring"],
    "Notable Victim 3": ["Abdur Razzaq Chitthi Wala, Age 81"]
}
df_casualties = pd.DataFrame(casualties_data)
df_casualties
# Out:
#    Death Toll  Confirmed Deaths  Survivors        Survivor Name  \
# 0         265               241          1  Vishwaskumar Ramesh
#
#                                  Notable Victim 1  \
# 0  Vijay Rupani, Former Chief Minister of Gujarat
#
#                                     Notable Victim 2  \
# 0  Payal Khatik, Student, supported family throug...
#
#                     Notable Victim 3
# 0  Abdur Razzaq Chitthi Wala, Age 81

# %% [markdown]
# ## 📌 4. Emergency Response Data

# %%
emergency_response_data = {
    "Teams Involved": ["Six NDRF teams, Fire engines, Ambulances, Police units"],
    "Actions": ["Immediate mobilization, Debris removal, DNA sampling, 6 bodies handed over"],
    "Assistance Centers": ["Ahmedabad, Mumbai, Delhi, Gatwick"],
    "Hotline India": ["1800 5691 444"],
    "Hotline International": ["+91 8062779200"],
    "Airport Status": ["Fully operational"],
    "Airport Helplines": ["+91 99741 11327, 079-29900291, 079-29900391"],
    "DNA Control Room": ["+91 6357373831, +91 6357373841"]
}
df_emergency_response = pd.DataFrame(emergency_response_data)
df_emergency_response
# Out:
#                                       Teams Involved  \
# 0  Six NDRF teams, Fire engines, Ambulances, Poli...
#
#                                              Actions  \
# 0  Immediate mobilization, Debris removal, DNA sa...
#
#                   Assistance Centers  Hotline India Hotline International  \
# 0  Ahmedabad, Mumbai, Delhi, Gatwick  1800 5691 444        +91 8062779200
#
#       Airport Status                            Airport Helplines  \
# 0  Fully operational  +91 99741 11327, 079-29900291, 079-29900391
#
#                  DNA Control Room
# 0  +91 6357373831, +91 6357373841

# %% [markdown]
# ## 📌 5. Key Personnel

# %%
key_personnel_data = [
    {"Name": "Captain Sumeet Sabharwal", "Role": "Commander", "Experience": "8200 hours", "Details": "Experienced pilot, no complaints, calm and professional"},
    {"Name": "Clive Kunder", "Role": "First Officer", "Experience": "1100 hours", "Details": "From coastal Karnataka, 1500 hours required to be commander"},
    {"Name": "Narendra Modi", "Role": "Prime Minister of India", "Experience": None, "Details": "Visited crash site, met survivor, reviewed operations"},
    {"Name": "Bhupendra Patel", "Role": "Chief Minister of Gujarat", "Experience": None, "Details": "Accompanied PM Modi"},
    {"Name": "Ram Mohan Naidu Kinjarapu", "Role": "Union Civil Aviation Minister", "Experience": None, "Details": "Accompanied PM Modi"},
    {"Name": "Harsh Sanghavi", "Role": "Gujarat Home Minister", "Experience": None, "Details": "Visited Civil Hospital"}
]
df_key_personnel = pd.DataFrame(key_personnel_data)
df_key_personnel
# Out:
#                         Name                           Role  Experience  \
# 0   Captain Sumeet Sabharwal                      Commander  8200 hours
# 1               Clive Kunder                  First Officer  1100 hours
# 2              Narendra Modi        Prime Minister of India        None
# 3            Bhupendra Patel      Chief Minister of Gujarat        None
# 4  Ram Mohan Naidu Kinjarapu  Union Civil Aviation Minister        None
# 5             Harsh Sanghavi          Gujarat Home Minister        None
#
#                                              Details
# 0  Experienced pilot, no complaints, calm and pro...
# 1  From coastal Karnataka, 1500 hours required to...
# 2  Visited crash site, met survivor, reviewed ope...
# 3                                Accompanied PM Modi
# 4                                Accompanied PM Modi
# 5                             Visited Civil Hospital

# %% [markdown]
# ## 📌 6. Official Statements

# %%
official_statements_data = [
    {"Source": "Narendra Modi", "Statement": "The tragedy in Ahmedabad has stunned and saddened us..."},
    {"Source": "Sanat Kaul", "Statement": "DGCA flagged safety lapses at Air India multiple times..."},
    {"Source": "Jitender Bhargava", "Statement": "First Dreamliner accident. Full investigation needed."},
    {"Source": "Om Birla", "Statement": "Whole country stands with families of deceased..."},
    {"Source": "Bhajanlal Sharma", "Statement": "Demise of Vijay Rupani in crash is extremely sad."}
]
df_official_statements = pd.DataFrame(official_statements_data)
df_official_statements
# Out:
#               Source                                          Statement
# 0      Narendra Modi  The tragedy in Ahmedabad has stunned and sadde...
# 1         Sanat Kaul  DGCA flagged safety lapses at Air India multip...
# 2  Jitender Bhargava  First Dreamliner accident. Full investigation ...
# 3           Om Birla  Whole country stands with families of deceased...
# 4   Bhajanlal Sharma  Demise of Vijay Rupani in crash is extremely sad.

# %% [markdown]
# ## 📌 7. Investigation Status

# %%
investigation_data = {
    "Status": ["Ongoing"],
    "Involved Parties": ["DGCA, Boeing technical team, Air India"],
    "Key Questions": ["Cause of engine failure, Effectiveness of maintenance checks, ICAO regulation adherence"]
}
df_investigation = pd.DataFrame(investigation_data)
df_investigation
# Out:
#     Status                        Involved Parties  \
# 0  Ongoing  DGCA, Boeing technical team, Air India
#
#                                        Key Questions
# 0  Cause of engine failure, Effectiveness of main...

# %% [markdown]
# ## 📌 8. Public Reaction

# %%
public_reaction_data = [
    {"Source": "Local Resident", "Statement": "Thorough investigation needed. Air India must take responsibility..."},
    {"Source": "Bhoomi Chauhan", "Statement": "Missed flight by 10 minutes due to traffic. Thankful to be safe."},
    {"Source": "Eyewitness", "Statement": "Pulled bodies from debris. A fearful sight."}
]
df_public_reaction = pd.DataFrame(public_reaction_data)
df_public_reaction
# Out:
#            Source                                          Statement
# 0  Local Resident  Thorough investigation needed. Air India must ...
# 1  Bhoomi Chauhan  Missed flight by 10 minutes due to traffic. Th...
# 2      Eyewitness        Pulled bodies from debris. A fearful sight.

# %% [markdown]
# ## 📌 9. Basic Analytics

# %%
survivor_rate = df_casualties["Survivors"][0] / df_incident["Total People Onboard"][0] * 100
death_rate_confirmed = df_casualties["Confirmed Deaths"][0] / df_incident["Total People Onboard"][0] * 100

print(f"Survivor Rate: {survivor_rate:.2f}%")
print(f"Confirmed Death Rate: {death_rate_confirmed:.2f}%")
# Out:
# Survivor Rate: 0.41%
# Confirmed Death Rate: 99.59%

# %% [markdown]
# ## 📌 10. Visual: Death Toll Comparison

# %%
labels = ['Confirmed Deaths', 'Reported Death Toll']
values = [df_casualties["Confirmed Deaths"][0], df_casualties["Death Toll"][0]]

plt.figure(figsize=(6,4))
plt.bar(labels, values, color=["#d62728", "#ff7f0e"])
plt.title("Death Toll Analysis")
plt.ylabel("Number of Individuals")
plt.grid(axis="y", linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📌 11. Pilot Experience Gap

# %%
required_hours = 1500
co_pilot_hours = 1100
gap = required_hours - co_pilot_hours

print(f"Co-Pilot had {co_pilot_hours} flight hours.")
print(f"Gap to qualify as Commander: {gap} hours")
# Out:
# Co-Pilot had 1100 flight hours.
# Gap to qualify as Commander: 400 hours

# %% [markdown]
# ## 📌 12. Notable Victims List

# %%
notable_victims = [
    df_casualties["Notable Victim 1"][0],
    df_casualties["Notable Victim 2"][0],
    df_casualties["Notable Victim 3"][0]
]

print("Notable Victims in the Crash:")
for i, victim in enumerate(notable_victims, 1):
    print(f"{i}. {victim}")
# Out:
# Notable Victims in the Crash:
# 1. Vijay Rupani, Former Chief Minister of Gujarat
# 2. Payal Khatik, Student, supported family through tutoring
# 3. Abdur Razzaq Chitthi Wala, Age 81

# %% [markdown]
# ## 📌 13. Emergency Helplines Summary

# %%
print("Domestic Hotline:", df_emergency_response["Hotline India"][0])
print("International Hotline:", df_emergency_response["Hotline International"][0])
print("Airport Helplines:", df_emergency_response["Airport Helplines"][0])
print("DNA Control Room Helplines:", df_emergency_response["DNA Control Room"][0])
# Out:
# Domestic Hotline: 1800 5691 444
# International Hotline: +91 8062779200
# Airport Helplines: +91 99741 11327, 079-29900291, 079-29900391
# DNA Control Room Helplines: +91 6357373831, +91 6357373841

# %% [markdown]
# # Advance Analysis

# %% [markdown]
# ## ✅ 1. Survivor/Death Probability Breakdown

# %%
from matplotlib.ticker import PercentFormatter

# Breakdown of survival vs death
survival_stats = {
    "Survived": df_casualties["Survivors"][0],
    "Died (Confirmed)": df_casualties["Confirmed Deaths"][0]
}

plt.figure(figsize=(6,6))
plt.pie(
    survival_stats.values(),
    labels=survival_stats.keys(),
    autopct='%1.1f%%',
    startangle=90,
    colors=["#4daf4a", "#e41a1c"],
    explode=(0.1, 0)
)
plt.title("Survival vs Death Probability")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✅ 2. Pilot Qualification Impact

# %%
# Quantify co-pilot readiness as a percentage
readiness_percent = (df_key_personnel[df_key_personnel['Name'] == "Clive Kunder"]['Experience'].str.extract(r'(\\d+)').astype(float).values[0][0]) / 1500 * 100

print(f"Co-Pilot Readiness for Commander Role: {readiness_percent:.2f}%")
# Out:
# Co-Pilot Readiness for Commander Role: nan%

# %% [markdown]
# ## ✅ 3. Emergency Resource Allocation Pie

# %%
# Breakdown of emergency responses
resources = {
    "NDRF Teams": 6,
    "Airport Helplines": 3,
    "DNA Helplines": 2,
    "Bodies Handed Over": 6
}

plt.figure(figsize=(7, 7))
plt.pie(
    resources.values(),
    labels=resources.keys(),
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Set3.colors,
    explode=(0.1, 0, 0, 0.1)
)
plt.title("Emergency Response Allocation")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✅ 4. Time to DNA Match Estimate Bar Plot

# %%
plt.figure(figsize=(6,4))
plt.bar(["Expected DNA Match Days"], [3], color="#6a3d9a")
plt.ylabel("Days")
plt.title("Estimated Time for DNA Matching")
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✅ 5. Safety Incident Severity Score (Hypothetical Model)

# %%
# Hypothetical scoring model
severity_score = (
    (df_casualties["Confirmed Deaths"][0] / df_incident["Total People Onboard"][0]) * 50 +
    (265 - 241) * 0.2 +  # discrepancy in reported vs confirmed
    (1500 - 1100) * 0.05 +  # pilot readiness gap
    6 * 1.5  # NDRF teams
)

print(f"Estimated Incident Severity Score: {severity_score:.2f} / 100")
# Out:
# Estimated Incident Severity Score: 83.59 / 100

# %% [markdown]
# ## ✅ 6. Highlight Anomaly in Death Count (Over 100%)

# %%
death_rate_reported = df_casualties["Death Toll"][0] / df_incident["Total People Onboard"][0] * 100
if death_rate_reported > 100:
    print(f"⚠️ Anomaly Detected: Reported death rate is {death_rate_reported:.2f}%, which exceeds the total onboard. This indicates possible reporting errors or inclusion of ground casualties.")
# Out:
# ⚠️ Anomaly Detected: Reported death rate is 109.50%, which exceeds the total onboard. This indicates possible reporting errors or inclusion of ground casualties.

# %% [markdown]
# ## ✅ 7. AI-based Sentiment Score of Public & Official Reactions (Optional NLP)

# %%
from textblob import TextBlob

all_statements = pd.concat([
    df_official_statements['Statement'],
    df_public_reaction['Statement']
])

sentiments = all_statements.apply(lambda x: TextBlob(x).sentiment.polarity)
df_sentiment = pd.DataFrame({
    "Statement": all_statements,
    "Sentiment Score": sentiments
})
df_sentiment.sort_values(by="Sentiment Score")
# Out:
#                                            Statement  Sentiment Score
# 2        Pulled bodies from debris. A fearful sight.          -0.9000
# 4  Demise of Vijay Rupani in crash is extremely sad.          -0.5000
# 0  The tragedy in Ahmedabad has stunned and sadde...           0.0000
# 1  DGCA flagged safety lapses at Air India multip...           0.0000
# 0  Thorough investigation needed. Air India must ...           0.0000
# 1  Missed flight by 10 minutes due to traffic. Th...           0.1875
# 3  Whole country stands with families of deceased...           0.2000
# 2  First Dreamliner accident. Full investigation ...           0.3000

# %% [markdown]
# ## ✅ 8. Correlation Heatmap of All Numerical Metrics

# %%
# Define numerical data
common_data = {
    "Total_People_Onboard": [242],
    "Passengers": [230],
    "Crew": [12],
    "Death_Toll_Reported": [265],
    "Confirmed_Deaths": [241],
    "Survivors": [1],
    "Altitude_at_Crash_Feet": [425],
    "Captain_Flight_Hours": [8200],
    "Co_Pilot_Flight_Hours": [1100],
    "Required_Hours_for_Commander": [1500],
    "NDRF_Teams_Deployed": [6],
    "Bodies_Handed_Over": [6],
    "Assistance_Centers_Count": [4],
    "Airport_Helplines_Count": [3],
    "DNA_Control_Room_Helplines_Count": [2],
    "Days_for_DNA_Matching": [3]
}
df_common = pd.DataFrame(common_data)

# %%
import seaborn as sns

# Convert relevant numerical data
df_numeric = df_common.copy()
corr = df_numeric.corr()

plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Incident Metrics")
plt.tight_layout()
plt.show()
# Out:
# c:\Users\Pankaj\anaconda3\Lib\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# c:\Users\Pankaj\anaconda3\Lib\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)

# %% [markdown]
# ## ✅ 9. Projected Casualty Simulation (Monte Carlo Style)

# %%
# Simulate 1000 possible crash outcomes based on minor variations in survival odds
np.random.seed(42)
simulated_deaths = np.random.binomial(n=242, p=0.9959, size=1000)  # Based on confirmed death rate ~99.59%

plt.figure(figsize=(8, 5))
plt.hist(simulated_deaths, bins=30, color="#d62728", alpha=0.7)
plt.title("Simulated Casualty Distribution (1000 Runs)")
plt.xlabel("Simulated Confirmed Deaths")
plt.ylabel("Frequency")
plt.axvline(x=241, color='black', linestyle='--', label="Actual")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✅ 10. Timeline Impact Visualization

# %%
# Simplified visualization of key timeline events
events = [
    ("Takeoff", 0),
    ("Engine Stall", 1),
    ("Mayday Call", 2),
    ("Crash", 3),
    ("Fire Ignition", 4),
    ("Rescue Ops Start", 5)
]

labels, times = zip(*events)
plt.plot(times, [1]*len(times), 'ro-', linewidth=2, markersize=8)
plt.yticks([])
plt.xticks(times, labels, rotation=45)
plt.title("Crash Event Timeline")
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✅ 11. Fuel Load Impact Estimate on Fire Spread

# %%
# Hypothetical: heavier fuel = longer fire duration
fuel_load_kg = 8000  # Example heavy long-haul tank
burn_rate = 3.2  # kg/s, typical for post-crash fire
duration_sec = fuel_load_kg / burn_rate
minutes = duration_sec / 60

print(f"Estimated Fire Burn Duration: {minutes:.2f} minutes")
# Out:
# Estimated Fire Burn Duration: 41.67 minutes

# %% [markdown]
# ## ✅ 12. Risk Comparison with Historical Incidents

# %%
# Example risk scale (aircraft type × incident rate × operator history)
risk_score = (
    1.0  # Assume Dreamliner is modern, low base risk
    * 1.5  # Operator flagged for safety violations
    * 1.3  # Recent DGCA reports raise concern
)

print(f"Relative Risk Score for This Operator & Aircraft: {risk_score:.2f}")
# Out:
# Relative Risk Score for This Operator & Aircraft: 1.95

# %% [markdown]
# ## ✅ 13. Survivor Rate vs Aircraft Type Benchmark

# %%
# Known survivability stats from historical crashes
aircraft_survival = {
    "Boeing 737": 15.2,
    "Airbus A320": 12.7,
    "Boeing 787 Dreamliner": 0.4  # This crash only, but for benchmark
}

plt.figure(figsize=(6,4))
plt.bar(aircraft_survival.keys(), aircraft_survival.values(), color="#2ca02c")
plt.ylabel("Survivor Rate (%)")
plt.title("Aircraft Type vs Survivor Rate")
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✅ 14. Custom Severity Index (Weighted Model)

# %%
# Create weighted index (scale: 0 to 100)
severity_index = (
    (df_casualties["Confirmed Deaths"][0] / df_incident["Total People Onboard"][0]) * 50 +  # Casualty weight
    (6 + 3 + 2) * 2 +  # Emergency resources
    ((1500 - 1100) / 1500) * 10  # Pilot gap factor
)

print(f"🧮 Custom Incident Severity Index: {severity_index:.2f} / 100")
# Out:
# 🧮 Custom Incident Severity Index: 74.46 / 100

# %% [markdown]
# # Upto Todays Data Analysis

# %% [markdown]
# ## 📰 1. Updated Casualty & Severity Metrics

# %%
# # Updated numbers from today’s reports
# ground_fatalities = 28  # at least
# confirmed_flight_deaths = 241
# total_fatalities = confirmed_flight_deaths + ground_fatalities

# print(f"▶ Flight Fatalities: {confirmed_flight_deaths}")
# print(f"▶ Ground Fatalities (estimated): {ground_fatalities}")
# print(f"▶ Total Fatalities: {total_fatalities}")

# # Recalculate fatality rate
# fatality_rate = total_fatalities / df_incident["Total People Onboard"][0] * 100
# print(f"📉 Fatality Rate vs Onboard: {fatality_rate:.2f}%")


# Update with today’s confirmed ground fatalities
ground_fatalities = 28
confirmed_flight_deaths = df_casualties["Confirmed Deaths"][0]
total_fatalities_updated = confirmed_flight_deaths + ground_fatalities

fatality_rate_updated = total_fatalities_updated / df_incident["Total People Onboard"][0] * 100

print(f"Flight Fatalities: {confirmed_flight_deaths}")
print(f"Ground Fatalities: {ground_fatalities}")
print(f"📉 Updated Total Fatalities: {total_fatalities_updated}")
print(f"Updated Fatality Rate vs onboard: {fatality_rate_updated:.2f}%")
# Out:
# Flight Fatalities: 241
# Ground Fatalities: 28
# 📉 Updated Total Fatalities: 269
# Updated Fatality Rate vs onboard: 111.16%

# %% [markdown]
# ## 🛬 2. Altitude vs Crash Timeline Analysis

# %%
import pandas as pd

# Flight radar timestamps
data = {
    "Time_sec": [0, 15, 30, 45],
    "Altitude_ft": [0, 650, 230, 0]
}
df_flight_profile = pd.DataFrame(data)

plt.figure(figsize=(8,4))
plt.plot(df_flight_profile["Time_sec"], df_flight_profile["Altitude_ft"], marker='o')
plt.title("Flight Altitude vs Time Post-Takeoff")
plt.xlabel("Seconds after takeoff")
plt.ylabel("Altitude (ft)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🧯 3. Casualty Simulation Enhanced with Ground Risk

# %%
import numpy as np

ground_deaths = np.random.binomial(n=50, p=0.6, size=1000)
flight_deaths = np.random.binomial(n=242, p=confirmed_flight_deaths/242, size=1000)
total_sim_deaths = ground_deaths + flight_deaths

plt.figure(figsize=(8,5))
plt.hist(total_sim_deaths, bins=30, color="#8c564b", alpha=0.7)
plt.axvline(total_fatalities, color='black', linestyle='--', label="Actual ~269")
plt.title("Simulated Total Fatalities (Flight + Ground)")
plt.xlabel("Total Deaths")
plt.ylabel("Frequency")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np

np.random.seed(7)
ground = np.random.binomial(n=50, p=28/50, size=1000)
air = np.random.binomial(n=242, p=confirmed_flight_deaths/242, size=1000)
simulation_total = ground + air

plt.figure(figsize=(8,5))
plt.hist(simulation_total, bins=30, color="#7f7f7f", alpha=0.8)
plt.axvline(total_fatalities_updated, color='black', linestyle='--', label=f"Actual ≈ {total_fatalities_updated}")
plt.title("Simulated Total Fatalities (Flight + Ground)")
plt.xlabel("Total Fatalities")
plt.ylabel("Frequency")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🔧 4. Black Box & Investigation Readiness Score

# %%
score = 0
score += 50  # black box recovered
score += 20  # international (FAA/NTSB) support
score += 10  # DGCA oversight + inspections of 787 fleet

print(f"🔍 Investigation Readiness Score: {score} / 100")
# Out:
# 🔍 Investigation Readiness Score: 80 / 100

# %%
score = 0
if True: # black box recovered
    score += 40
if True: # international teams (US, UK, Boeing, GE) involved
    score += 30
if True: # regulator-led fleet inspections
    score += 20
if True: # cockpit voice recorder status uncertain
    score += 10

print(f"Investigation Readiness Score: {score} / 100")
# Out:
# Investigation Readiness Score: 100 / 100

# %% [markdown]
# ## ⚙ 5. Cause Probability Model

# %%
causes = {"Engine failure": 0.4, "Bird strike": 0.2, "Flap/gear error": 0.25, "Fuel issue": 0.15}
# Weighted probability pie chart
plt.figure(figsize=(6,6))
plt.pie(causes.values(), labels=causes.keys(), autopct='%1.1f%%', colors=plt.cm.Pastel1.colors)
plt.title("Preliminary Cause Probability (Hypothetical)")
plt.show()

# %%
# Based on emerging news themes
cause_weights = {
    "Engine/Thrust Loss": 0.45,
    "Double Engine Failure": 0.20,
    "Flight Configuration Error": 0.20,
    "Ground Obstruction/Birds": 0.10,
    "Other": 0.05
}
plt.figure(figsize=(6,6))
plt.pie(cause_weights.values(), labels=cause_weights.keys(), autopct="%1.1f%%", colors=plt.cm.Pastel2.colors)
plt.title("Preliminary Cause Probabilities")
plt.show()

# %% [markdown]
# ## ✈ 6. Flight: Sole Survivor Deep Dive

# %%
print("🧬 Survivor Insights:")
print("▶ Seat 11A – emergency exit row")
print("▶ Escaped via broken hatch – 'miracle of seat 11A' comments")
print("▶ British-Indian national, minor injuries but otherwise stable")
# Out:
# 🧬 Survivor Insights:
# ▶ Seat 11A – emergency exit row
# ▶ Escaped via broken hatch – 'miracle of seat 11A' comments
# ▶ British-Indian national, minor injuries but otherwise stable

# %%
survivor = {
    "Name": "Vishwashkumar Ramesh",
    "Nationality": "British–Indian",
    "Seat": "11A (Exit row)",
    "Escape": "Via emergency hatch"
}
print("🧬 Survivor Profile:")
for k,v in survivor.items():
    print(f"▶ {k}: {v}")
# Out:
# 🧬 Survivor Profile:
# ▶ Name: Vishwashkumar Ramesh
# ▶ Nationality: British–Indian
# ▶ Seat: 11A (Exit row)
# ▶ Escape: Via emergency hatch

# %% [markdown]
# ## 📊 7. Comparative Analysis with Past Indian Crashes

# %%
incidents = {
    "AI171_2025": total_fatalities_updated,
    "Indian113_1988": 133,
    "AIExpress812_2010": 158
}
plt.figure(figsize=(6,4))
plt.bar(incidents.keys(), incidents.values(), color=["#0055a4","#ff7f0e","#bcbd22"])
plt.ylabel("Fatalities")
plt.title("Ahmedabad 2025 vs Historic Indian Air Crashes")
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
